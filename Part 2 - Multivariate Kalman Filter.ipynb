# %% [markdown]
# # Part 2 - Multivariate Kalman Filter

# %% [markdown]
# ## 2.1 - Prerequisite knowledge for Multivariate Kalman Filter

# %% [markdown]
# ## 2.2 - Kalman Filter Equation Derivation

# %% [markdown]
# ## 2.3 - Implementation of a Kalman Filter Class
